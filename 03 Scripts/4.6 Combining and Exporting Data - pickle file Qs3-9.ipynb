# %% [markdown]
# # 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import prepared products_checked df
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Check output
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Define pickle file path
path = r'/Users/renataherrera/Documents/CF RH 2023-2024/CF DATA IMMERSION/CF RH A4 PYTHON/RH_PYTHON_Instacart Basket Analysis'

# %%
# Import orders_products_combined df from the pickle file
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#Check output
df_ords_prods_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    0           0   2539329        1    prior             1
# 2                    0           0   2539329        1    prior             1
# 3                    0           0   2539329        1    prior             1
# 4                    0           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 32434484       3421081     3421081   2977660   206209    prior            13
# 32434485       3421081     3421081   2977660   206209    prior            13
# 32434486       3421081     3421081   2977660   206209    prior            13
# 32434487       3421081     3421081   2977660   206209    prior            13
# 32434488       3421081     3421081   2977660   206209    prior            13
#
# ...

# %% [markdown]
# # 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
# Check dimensions -rows and columns
df_prods.shape
# Out:
# (49693, 6)

# %%
# Check dimensions-rows and columns of pickle file
df_ords_prods_combined.shape
# Out:
# (32434489, 13)

# %%
# Check output
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# # 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# Drop unnamed column in df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Also drop unnamed columns in df_ords_prods_combined
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', '_merge'])

# %%
#Check to display dropped column
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#Check to display dropped columns
df_ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_previous_order  product_id  \
# 0                  8                        NaN         196
# 1                  8                        NaN       14084
# 2                  8                        NaN       12427
# 3                  8                        NaN       26088
# 4                  8                        NaN       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# 3                  4          0
# 4                  5          0

# %% [markdown]
# # 5 A suitable way to combine the orders_products_combined dataframe with your products data set is by a column found in both dataframes--in this case product_id

# %%
# Merging the prepared data df's--orders_products_combined AND products_checked
# by product_id column
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %% [markdown]
# # 6. Confirm the results of the merge using the merge flag.

# %%
# Checking results of merged df
df_ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_previous_order  product_id  \
# 0                  8                        NaN         196
# 1                  7                       15.0         196
# 2                 12                       21.0         196
# 3                  7                       29.0         196
# 4                 15                       28.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          0         Soda        77              7     9.0
# ...

# %%
# Checking the _merge column values
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Checking the merged dimensions-rows, columns
df_ords_prods_merged.shape
# Out:
# (32434212, 15)

# %% [markdown]
# # 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
#Define path
path = r'/Users/renataherrera/Documents/CF RH 2023-2024/CF DATA IMMERSION/CF RH A4 PYTHON/RH_PYTHON_Instacart Basket Analysis'

# %%
# Check path
path
# Out:
# '/Users/renataherrera/Documents/CF RH 2023-2024/CF DATA IMMERSION/CF RH A4 PYTHON/RH_PYTHON_Instacart Basket Analysis'

# %%
#Export orders_products_merged into Prepared Data
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# # 8. Ensure your notebooks and Instacart project folder are organized and that comments and section headings have been used throughout your code. All your exported data files should be effectively labeled and stored in your “Data” folder.

# %% [markdown]
# # 9.Save the two notebooks and send them to your tutor along with a screenshot of the exported datasets in your Instacart project folder.
